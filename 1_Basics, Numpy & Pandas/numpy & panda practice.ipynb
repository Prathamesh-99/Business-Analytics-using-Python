# %% [markdown]
# # Numpy

# %%
import numpy as np

# %%
simple_list=[1,2,3]
np.array(simple_list)

# %%
Array=np.array([1,2,2,3])
Array

# %%
Matrix=[1,2,3],[4,5,6],[7,8,9]
np.array(Matrix)
type(Matrix)

# %%
np.linspace(0,20,10)

# %%
np.random.rand(2,5)

# %%
np.random.randint(2,5,2)

# %%
Array=np.array([5,10,15,20,25,30,35,40])
Array

# %%
np.mean(Array)

# %%
np.median(Array)

# %%
np.std(Array)

# %%
np.var(Array)

# %%
np.square(Array)

# %%
np.sqrt(Array)

# %%
np.exp(Array)

# %%
np.log(Array)

# %%
np.sum(Array)

# %%
np.sum(np.square(Array))

# %%
import pandas as pd
import numpy as np

# %%
Table=pd.DataFrame(np.random.rand(8,8),index=['1','2','3','4','5','6','7','8'],columns=['A','B','C','D','E','F','G','H'])
Table
# Out:
#           A         B         C         D         E         F         G  \
# 1  0.797010  0.914908  0.756399  0.831756  0.057638  0.666610  0.387885
# 2  0.411579  0.676259  0.226702  0.782094  0.157198  0.417203  0.787913
# 3  0.148350  0.613269  0.674214  0.336161  0.983972  0.296162  0.102804
# 4  0.708956  0.239610  0.661752  0.400432  0.582817  0.065043  0.740412
# 5  0.332218  0.412911  0.070219  0.785379  0.086438  0.210680  0.307425
# 6  0.256199  0.804319  0.660660  0.940553  0.416024  0.937121  0.668243
# 7  0.103441  0.707941  0.540682  0.093477  0.030636  0.488750  0.765107
# 8  0.205356  0.628573  0.184566  0.782860  0.810351  0.533019  0.621783
#
#           H
# 1  0.730438
# 2  0.129745
# 3  0.384509
# 4  0.716327
# 5  0.044038
# 6  0.447232
# 7  0.109716
# 8  0.424501

# %%
Table[['A','B']]
# Out:
#           A         B
# 1  0.797010  0.914908
# 2  0.411579  0.676259
# 3  0.148350  0.613269
# 4  0.708956  0.239610
# 5  0.332218  0.412911
# 6  0.256199  0.804319
# 7  0.103441  0.707941
# 8  0.205356  0.628573

# %%
Table['Z']=Table['B']+Table['C']
Table
# Out:
#           A         B         C         D         E         F         G  \
# 1  0.797010  0.914908  0.756399  0.831756  0.057638  0.666610  0.387885
# 2  0.411579  0.676259  0.226702  0.782094  0.157198  0.417203  0.787913
# 3  0.148350  0.613269  0.674214  0.336161  0.983972  0.296162  0.102804
# 4  0.708956  0.239610  0.661752  0.400432  0.582817  0.065043  0.740412
# 5  0.332218  0.412911  0.070219  0.785379  0.086438  0.210680  0.307425
# 6  0.256199  0.804319  0.660660  0.940553  0.416024  0.937121  0.668243
# 7  0.103441  0.707941  0.540682  0.093477  0.030636  0.488750  0.765107
# 8  0.205356  0.628573  0.184566  0.782860  0.810351  0.533019  0.621783
#
#           H         Z
# 1  0.730438  1.671308
# 2  0.129745  0.902960
# 3  0.384509  1.287483
# 4  0.716327  0.901362
# 5  0.044038  0.483130
# 6  0.447232  1.464980
# 7  0.109716  1.248623
# 8  0.424501  0.813140

# %%
Table.drop('G',axis=1)
# Out:
#           A         B         C         D         E         F         H  \
# 1  0.797010  0.914908  0.756399  0.831756  0.057638  0.666610  0.730438
# 2  0.411579  0.676259  0.226702  0.782094  0.157198  0.417203  0.129745
# 3  0.148350  0.613269  0.674214  0.336161  0.983972  0.296162  0.384509
# 4  0.708956  0.239610  0.661752  0.400432  0.582817  0.065043  0.716327
# 5  0.332218  0.412911  0.070219  0.785379  0.086438  0.210680  0.044038
# 6  0.256199  0.804319  0.660660  0.940553  0.416024  0.937121  0.447232
# 7  0.103441  0.707941  0.540682  0.093477  0.030636  0.488750  0.109716
# 8  0.205356  0.628573  0.184566  0.782860  0.810351  0.533019  0.424501
#
#           Z
# 1  1.671308
# 2  0.902960
# 3  1.287483
# 4  0.901362
# 5  0.483130
# 6  1.464980
# 7  1.248623
# 8  0.813140

# %%
Table.drop('5')
# Out:
#           A         B         C         D         E         F         G  \
# 1  0.797010  0.914908  0.756399  0.831756  0.057638  0.666610  0.387885
# 2  0.411579  0.676259  0.226702  0.782094  0.157198  0.417203  0.787913
# 3  0.148350  0.613269  0.674214  0.336161  0.983972  0.296162  0.102804
# 4  0.708956  0.239610  0.661752  0.400432  0.582817  0.065043  0.740412
# 6  0.256199  0.804319  0.660660  0.940553  0.416024  0.937121  0.668243
# 7  0.103441  0.707941  0.540682  0.093477  0.030636  0.488750  0.765107
# 8  0.205356  0.628573  0.184566  0.782860  0.810351  0.533019  0.621783
#
#           H         Z
# 1  0.730438  1.671308
# 2  0.129745  0.902960
# 3  0.384509  1.287483
# 4  0.716327  0.901362
# 6  0.447232  1.464980
# 7  0.109716  1.248623
# 8  0.424501  0.813140

# %%
Table.reset_index()
# Out:
#   index         A         B         C         D         E         F         G  \
# 0     1  0.797010  0.914908  0.756399  0.831756  0.057638  0.666610  0.387885
# 1     2  0.411579  0.676259  0.226702  0.782094  0.157198  0.417203  0.787913
# 2     3  0.148350  0.613269  0.674214  0.336161  0.983972  0.296162  0.102804
# 3     4  0.708956  0.239610  0.661752  0.400432  0.582817  0.065043  0.740412
# 4     5  0.332218  0.412911  0.070219  0.785379  0.086438  0.210680  0.307425
# 5     6  0.256199  0.804319  0.660660  0.940553  0.416024  0.937121  0.668243
# 6     7  0.103441  0.707941  0.540682  0.093477  0.030636  0.488750  0.765107
# 7     8  0.205356  0.628573  0.184566  0.782860  0.810351  0.533019  0.621783
#
#           H         Z
# 0  0.730438  1.671308
# 1  0.129745  0.902960
# 2  0.384509  1.287483
# 3  0.716327  0.901362
# 4  0.044038  0.483130
# 5  0.447232  1.464980
# 6  0.109716  1.248623
# 7  0.424501  0.813140

# %%
Table2={'Sr No.': [1100,1101,1102,1103], 'Item': ['Earphone','Mobile','Charger','Laptop'], 'Quantity': [2,3,5,6]}
Table=pd.DataFrame(Table2)
Table
# Out:
#    Sr No.      Item  Quantity
# 0    1100  Earphone         2
# 1    1101    Mobile         3
# 2    1102   Charger         5
# 3    1103    Laptop         6

# %% [markdown]
# # THE END
